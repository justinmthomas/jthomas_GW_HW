# %%
# Dependencies
# Dependencies
import pandas as pd

# %%
# load CSV
df = pd.read_csv("Resources/2016-FCC-New-Coders-Survey-Data.csv", encoding='iso-8859-1', low_memory=False)
df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo  BootcampMonthsAgo BootcampName  BootcampPostSalary  \
# 0                NaN                NaN          NaN                 NaN
# 1                NaN                NaN          NaN                 NaN
# 2                NaN                NaN          NaN                 NaN
# 3                NaN                NaN          NaN                 NaN
# 4                NaN                NaN          NaN                 NaN
#
#    BootcampRecommend  ChildrenNumber  ... ResourceSoloLearn  \
# 0                NaN             NaN  ...               NaN
# ...

# %%
# Read with pandas--low_memory required to suppress errors about mixed data types

# %%
# Take only columns 0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111

columns = [0, 1, 2, 3, 4, 6, 7, 8, 9, 10, 11, 29, 30, 32, 36, 37, 45, 48, 56, 110, 111]
extract_df = df.iloc[:,columns]
extract_df.head()
# Out:
#     Age  AttendedBootcamp  BootcampFinish  BootcampFullJobAfter  \
# 0  28.0               0.0             NaN                   NaN
# 1  22.0               0.0             NaN                   NaN
# 2  19.0               0.0             NaN                   NaN
# 3  26.0               0.0             NaN                   NaN
# 4  20.0               0.0             NaN                   NaN
#
#    BootcampLoanYesNo BootcampName  BootcampPostSalary  BootcampRecommend  \
# 0                NaN          NaN                 NaN                NaN
# 1                NaN          NaN                 NaN                NaN
# 2                NaN          NaN                 NaN                NaN
# 3                NaN          NaN                 NaN                NaN
# 4                NaN          NaN                 NaN                NaN
#
#    ChildrenNumber                 CityPopulation  ...  \
# 0             NaN  between 100,000 and 1 million  ...
# ...

# %%
# Change reading 0 and 1 to No and Yes, respectively
extract_df_replace = extract_df.replace({0.0: "No", 1.0:"Yes"})
#extract_df['AttendedBootcamp'] = extract_df['AttendedBootcamp'].apply(lambda x: 0 if x=='no' else 1)
extract_df_replace
# Out:
#         Age AttendedBootcamp BootcampFinish BootcampFullJobAfter  \
# 0      28.0               No            NaN                  NaN
# 1      22.0               No            NaN                  NaN
# 2      19.0               No            NaN                  NaN
# 3      26.0               No            NaN                  NaN
# 4      20.0               No            NaN                  NaN
# 5      34.0               No            NaN                  NaN
# 6      23.0               No            NaN                  NaN
# 7      35.0               No            NaN                  NaN
# 8      33.0               No            NaN                  NaN
# 9      33.0               No            NaN                  NaN
# 10     57.0               No            NaN                  NaN
# 11     23.0               No            NaN                  NaN
# 12     47.0               No            NaN                  NaN
# ...

# %%
# Extract rows for only those who attended a bootcamp
attended_bootcamp = extract_df_replace.loc[extract_df_replace["AttendedBootcamp"] == "Yes"]
attended_bootcamp.count()
# Out:
# Age                     818
# AttendedBootcamp        953
# BootcampFinish          933
# BootcampFullJobAfter    635
# BootcampLoanYesNo       934
# BootcampName            895
# BootcampPostSalary      330
# BootcampRecommend       937
# ChildrenNumber          148
# CityPopulation          823
# CodeEventBootcamp        27
# CountryLive             825
# EmploymentField         476
# EmploymentStatus        792
# Gender                  833
# HasChildren             211
# HoursLearning           925
# Income                  430
# JobRoleInterest         402
# SchoolDegree            832
# SchoolMajor             622
# dtype: int64

# %%
# Create DataFrame of the different boot camps that had a significant number of attendees
significant_attendees = attended_bootcamp.groupby("BootcampName")

significant_attendees.head()

count_by_camp = significant_attendees["AttendedBootcamp"].count() 
count_by_camp

count_by_camp_df = pd.DataFrame({"count_by_camp": count_by_camp})
count_by_camp_df
# Sort in descending order 
count_by_camp_df = count_by_camp_df.sort_values(["count_by_camp"], ascending=False)
count_by_camp_df
# Out:
#                                                     count_by_camp
# BootcampName
# General Assembly                                               90
# Flatiron School                                                54
# Dev Bootcamp                                                   48
# The Iron Yard                                                  40
# Prime Digital Academy                                          30
# Hack Reactor                                                   29
# Turing                                                         27
# App Academy                                                    22
# Hackbright Academy                                             22
# Bloc.io                                                        21
# Code Fellows                                                   21
# MakerSquare                                                    20
# Galvanize                                                      20
# ...

# %%
# Count how many attendees of each bootcamp would recommend the bootcamp
recommend_by_camp = significant_attendees["BootcampRecommend"].count() 
recommend_by_camp

#recommend_bootcamp = pd.DataFrame(recommend_by_camp.groupby("BootcampName")["BootcampRecommend"].sum())
#recommend_bootcamp.reset_index(inplace=True)
# Out:
# BootcampName
# 10x.org.il                   5
# 4Geeks Academy               7
# AcadGild                     2
# Academia de CÃ³digo          4
# Academic Work Academy        0
# Academy X                    1
# Ada                          9
# Alphappl                     0
# AngelHack Education          1
# Anyone Can Learn To Code     7
# App Academy                 22
# Astro Code School            1
# Atlanta Code                 1
# Austin Coding Academy        1
# Base10 Academy               1
# Betamore                     1
# Big Nerd Ranch               2
# Bit Bootcamp                 3
# Bitmaker Labs                5
# Bloc.io                     21
# BoiseCodeWorks               2
# BrainStation                 3
# Byte Academy                 1
# CODEcamp Charleston          2
# Camp Code Away               3
# CareerFoundry                5
# Claim Academy                1
# Code 42                      1
# Code Fellows                21
# ...

# %%
# Merge the two created data frames on the name of tbe bootcamp

df_merge_bootcamp = pd.merge(recommend_by_camp, count_by_camp_df, on='BootcampName')

# %%
# Calculate percentage of eac bootcamp's students who are recommenders
df_merge_bootcamp["Percent_Reccomend"] = (df_merge_bootcamp["BootcampRecommend"] / df_merge_bootcamp["count_by_camp"])*100
df_merge_bootcamp.reset_index(inplace=True)
df_merge_bootcamp.head()
df_merge_bootcamp['Percent_Reccomend'] = df_merge_bootcamp['Percent_Reccomend'].map('{:,.2f}%'.format)
df_merge_bootcamp
# Out:
#                  BootcampName  BootcampRecommend  count_by_camp  \
# 0                  10x.org.il                  5              5
# 1              4Geeks Academy                  7              8
# 2                    AcadGild                  2              2
# 3         Academia de CÃ³digo                  4              4
# 4       Academic Work Academy                  0              1
# 5                   Academy X                  1              1
# 6                         Ada                  9              9
# 7                    Alphappl                  0              1
# 8         AngelHack Education                  1              1
# 9    Anyone Can Learn To Code                  7              7
# 10                App Academy                 22             22
# 11          Astro Code School                  1              1
# 12               Atlanta Code                  1              1
# 13      Austin Coding Academy                  1              1
# ...

# %%
# Export to excel and remove index

df_merge_bootcamp.to_excel("output/thomasbootcampoutput2.xlsx", index=False)
